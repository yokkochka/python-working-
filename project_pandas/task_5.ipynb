# %%
import pandas as pd

# %%
df = pd.read_csv("./csv/clear_data.csv")

# %%
df_2007 = df[df["Year"] == 2007]
df_2007
# Out:
#                   Country ISO3  Year  Population  Population Growth  \
# 47            Afghanistan  AFG  2007    27100536           667487.0
# 106               Albania  ALB  2007     2970017           -22530.0
# 165               Algeria  DZA  2007    34166972           525970.0
# 224        American Samoa  ASM  2007       58365             -742.0
# 283               Andorra  AND  2007       82684             1691.0
# ...                   ...  ...   ...         ...                ...
# 15161  West Bank and Gaza  PSE  2007     3494496            88162.0
# 15220               World  WLD  2007  6675130418         81507216.0
# 15279         Yemen, Rep.  YEM  2007    21282515           594869.0
# 15338              Zambia  ZMB  2007    12502958           329444.0
# 15397            Zimbabwe  ZWE  2007    12255922           100431.0
#
#        Growth Rate (%) Decade
# 47            2.525199  2000s
# 106          -0.752870  2000s
# 165           1.563479  2000s
# 224          -1.255350  2000s
# 283           2.087835  2000s
# ...                ...    ...
# 15161         2.588178  2000s
# 15220         1.236152  2000s
# 15279         2.875479  2000s
# 15338         2.706236  2000s
# 15397         0.826219  2000s
#
# [263 rows x 7 columns]

# %%
top5 = df_2007.sort_values("Population", ascending=False).head(5)
top5
# Out:
#                    Country ISO3  Year  Population  Population Growth  \
# 15220                World  WLD  2007  6675130418         81507216.0
# 6176      IDA & IBRD total  IBT  2007  5571274179         72594310.0
# 8356   Low & middle income  LMY  2007  5542975651         72574970.0
# 9477         Middle income  MIC  2007  5010312065         58008821.0
# 6117             IBRD only  IBD  2007  4291629776         43012029.0
#
#        Growth Rate (%) Decade
# 15220         1.236152  2000s
# 6176          1.320213  2000s
# 8356          1.326685  2000s
# 9477          1.171350  2000s
# 6117          1.012377  2000s

# %%
world_population = df_2007["Population"].sum()
world_population
# Out:
# np.int64(70266011453)

# %%
top5["Share (%)"] = (top5["Population"] / world_population) * 100
top5
# Out:
#                    Country ISO3  Year  Population  Population Growth  \
# 15220                World  WLD  2007  6675130418         81507216.0
# 6176      IDA & IBRD total  IBT  2007  5571274179         72594310.0
# 8356   Low & middle income  LMY  2007  5542975651         72574970.0
# 9477         Middle income  MIC  2007  5010312065         58008821.0
# 6117             IBRD only  IBD  2007  4291629776         43012029.0
#
#        Growth Rate (%) Decade  Share (%)
# 15220         1.236152  2000s   9.499800
# 6176          1.320213  2000s   7.928832
# 8356          1.326685  2000s   7.888559
# 9477          1.171350  2000s   7.130492
# 6117          1.012377  2000s   6.107689

# %%
d =  100 - top5["Share (%)"].sum()
d
# Out:
# np.float64(61.444628023150244)

# %%
world_population
# Out:
# np.int64(70266011453)

# %%
top5.loc[5] = ["OTHER", ' ', 2007, world_population, 0,  0,  '2000s', d]
top5
# Out:
#                    Country ISO3  Year   Population  Population Growth  \
# 15220                World  WLD  2007   6675130418         81507216.0
# 6176      IDA & IBRD total  IBT  2007   5571274179         72594310.0
# 8356   Low & middle income  LMY  2007   5542975651         72574970.0
# 9477         Middle income  MIC  2007   5010312065         58008821.0
# 6117             IBRD only  IBD  2007   4291629776         43012029.0
# 5                    OTHER       2007  70266011453                0.0
#
#       Growth Rate (%) Decade  Share (%)
# 15220        1.236152  2000s   9.499800
# 6176         1.320213  2000s   7.928832
# 8356         1.326685  2000s   7.888559
# 9477          1.17135  2000s   7.130492
# 6117         1.012377  2000s   6.107689
# 5                   0  2000s  61.444628

# %%
top5.plot(
    kind = "pie",
    y = "Share (%)",
    labels = top5["Country"],
    figsize = (8, 8),
    autopct = "%1.1f%%"



)
# Out:
# <Axes: ylabel='Share (%)'>
